# %%
import csv
import matplotlib.pyplot as plt

# %%
print("lendo o documento...")
with open("chicago.csv", "r") as file_read:
    reader = csv.reader(file_read)
    data_list = list(reader)
print("OK!")
# Out:
# lendo o documento...
# OK!

# %%
# Vamos verificar quantas linhas nós temos
print("Número de linhas:")
print(len(data_list))
# Out:
# Número de linhas:
# 1551506

# %%
# Imprimindo a primeira linha de data_list para verificar se funcionou.
print("Linha 0: ")
print(data_list[0])
# É o cabeçalho dos dados, para que possamos identificar as colunas.
# Out:
# Linha 0:
# ['Start Time', 'End Time', 'Trip Duration', 'Start Station', 'End Station', 'User Type', 'Gender', 'Birth Year']

# %%
# Imprimindo a segunda linha de data_list, ela deveria conter alguns dados
print("Linha 1: ")
print(data_list[1])
# Out:
# Linha 1:
# ['2017-01-01 00:00:36', '2017-01-01 00:06:32', '356', 'Canal St & Taylor St', 'Canal St & Monroe St (*)', 'Customer', '', '']

# %%
input("Aperte Enter para continuar...")
# TAREFA 1
# TODO: Imprima as primeiras 20 linhas usando um loop para identificar os dados.
print("\n\nTAREFA 1: Imprimindo as primeiras 20 amostras")
for dado in range(1, 21):
  print("dado: " + str(dado), data_list[dado])
# Out:
# Aperte Enter para continuar...
#
#
# TAREFA 1: Imprimindo as primeiras 20 amostras
# dado: 1 ['2017-01-01 00:00:36', '2017-01-01 00:06:32', '356', 'Canal St & Taylor St', 'Canal St & Monroe St (*)', 'Customer', '', '']
# dado: 2 ['2017-01-01 00:02:54', '2017-01-01 00:08:21', '327', 'Larrabee St & Menomonee St', 'Sheffield Ave & Kingsbury St', 'Subscriber', 'Male', '1984.0']
# dado: 3 ['2017-01-01 00:06:06', '2017-01-01 00:18:31', '745', 'Orleans St & Chestnut St (NEXT Apts)', 'Ashland Ave & Blackhawk St', 'Subscriber', 'Male', '1985.0']
# dado: 4 ['2017-01-01 00:07:28', '2017-01-01 00:12:51', '323', 'Franklin St & Monroe St', 'Clinton St & Tilden St', 'Subscriber', 'Male', '1990.0']
# dado: 5 ['2017-01-01 00:07:57', '2017-01-01 00:20:53', '776', 'Broadway & Barry Ave', 'Sedgwick St & North Ave', 'Subscriber', 'Male', '1990.0']
# dado: 6 ['2017-01-01 00:10:44', '2017-01-01 00:21:27', '643', 'State St & Kinzie St', 'Wells St & Polk St', 'Subscriber', 'Male', '1970.0']
# ...

# %%
# Vamos mudar o data_list para remover o cabeçalho dele.
data_list = data_list[1:]

# %%
data_list[3][6]
# Out:
# 'Male'

# %%
# Nós podemos acessar as features pelo índice
# Por exemplo: sample[6] para imprimir gênero, ou sample[-2]

# %%
input("Aperte Enter para continuar...")
# TAREFA 2
# TODO: Imprima o `gênero` das primeiras 20 linhas

print("\nTAREFA 2: Imprimindo o gênero das primeiras 20 amostras")
for genero in range(0,20):
    print("Genero: " + str(genero), data_list[genero][6])
# Out:
# Aperte Enter para continuar...
#
# TAREFA 2: Imprimindo o gênero das primeiras 20 amostras
# Genero: 0
# Genero: 1 Male
# Genero: 2 Male
# Genero: 3 Male
# Genero: 4 Male
# Genero: 5 Male
# Genero: 6 Male
# Genero: 7
# Genero: 8
# Genero: 9
# Genero: 10 Female
# Genero: 11
# Genero: 12 Male
# Genero: 13 Male
# Genero: 14 Female
# Genero: 15 Male
# Genero: 16 Male
# Genero: 17 Male
# Genero: 18 Female
# Genero: 19 Male

# %%
# Ótimo! Nós podemos pegar as linhas(samples) iterando com um for, e as colunas(features) por índices.
# Mas ainda é difícil pegar uma coluna em uma lista. Exemplo: Lista com todos os gêneros

# %%
input("Aperte Enter para continuar...")
# TAREFA 3
# TODO: Crie uma função para adicionar as colunas(features) de uma lista em outra lista, na mesma ordem
def column_to_list(data, index):
    column_list = []
    # Dica: Você pode usar um for para iterar sobre as amostras, pegar a feature pelo seu índice, e dar append para uma lista
    for dado in range(len(data)):
        column_list.append(data[dado][index])
    return column_list
# Out:
# Aperte Enter para continuar...

# %%
# Vamos checar com os gêneros se isso está funcionando (apenas para os primeiros 20)
print("\nTAREFA 3: Imprimindo a lista de gêneros das primeiras 20 amostras")
print(column_to_list(data_list, -2)[:20])
# Out:
# TAREFA 3: Imprimindo a lista de gêneros das primeiras 20 amostras
# ['', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', '', '', '', 'Female', '', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male']

# %%
# ------------ NÃO MUDE NENHUM CÓDIGO AQUI ------------
assert type(column_to_list(data_list, -2)) is list, "TAREFA 3: Tipo incorreto retornado. Deveria ser uma lista."
assert len(column_to_list(data_list, -2)) == 1551505, "TAREFA 3: Tamanho incorreto retornado."
assert column_to_list(data_list, -2)[0] == "" and column_to_list(data_list, -2)[1] == "Male", "TAREFA 3: A lista não coincide."
# -----------------------------------------------------

# %%
input("Aperte Enter para continuar...")
# Agora sabemos como acessar as features, vamos contar quantos Male (Masculinos) e Female (Femininos) o dataset tem
# TAREFA 4
# TODO: Conte cada gênero. Você não deveria usar uma função parTODO isso.
male = 0
female = 0
for genero in range(len(data_list)):
    if (data_list[genero][6] == "Male"):
        male = male + 1
    elif (data_list[genero][6] == "Female"):
        female = female + 1

print(male)
print(female)
# Out:
# Aperte Enter para continuar...
# 935854
# 298784

# %%
#data_list[6]

# %%
# Verificando o resultado
print("\nTAREFA 4: Imprimindo quantos masculinos e femininos nós encontramos")
print("Masculinos: ", male, "\nFemininos: ", female)
# Out:
# TAREFA 4: Imprimindo quantos masculinos e femininos nós encontramos
# Masculinos:  935854
# Femininos:  298784

# %%
# ------------ NÃO MUDE NENHUM CÓDIGO AQUI ------------
assert male == 935854 and female == 298784, "TAREFA 4: A conta não bate."
# -----------------------------------------------------

# %%
input("Aperte Enter para continuar...")
# Por que nós não criamos uma função parTODO isso?
# TAREFA 5
# TODO: Crie uma função para contar os gêneros. Retorne uma lista.
# Isso deveria retornar uma lista com [count_male, count_female] (exemplo: [10, 15] significa 10 Masculinos, 15 Femininos)
def count_gender(data_list):
    male = 0
    female = 0
    for genero in range(len(data_list)):
        if (data_list[genero][6] == "Male"):
            male = male + 1
        elif (data_list[genero][6] == "Female"):
            female = female + 1
    return [male, female]
# Out:
# Aperte Enter para continuar...

# %%
print("\nTAREFA 5: Imprimindo o resultado de count_gender")
print(count_gender(data_list))
# Out:
# TAREFA 5: Imprimindo o resultado de count_gender
# [935854, 298784]

# %%
# ------------ NÃO MUDE NENHUM CÓDIGO AQUI ------------
assert type(count_gender(data_list)) is list, "TAREFA 5: Tipo incorreto retornado. Deveria retornar uma lista."
assert len(count_gender(data_list)) == 2, "TAREFA 5: Tamanho incorreto retornado."
assert count_gender(data_list)[0] == 935854 and count_gender(data_list)[1] == 298784, "TAREFA 5: Resultado incorreto no retorno!"
# -----------------------------------------------------

# %%
input("Aperte Enter para continuar...")
# Agora que nós podemos contar os usuários, qual gênero é mais prevalente?
# TAREFA 6
# TODO: Crie uma função que pegue o gênero mais popular, e retorne este gênero como uma string.
# Esperamos ver "Masculino", "Feminino", ou "Igual" como resposta.
def most_popular_gender(data_list):
    count_gender(data_list)
    
    if male > female:
        answer = "Masculino"
    else:
        answer = "Feminino"
    return answer
# Out:
# Aperte Enter para continuar...

# %%
count_gender(data_list)
# Out:
# [935854, 298784]

# %%
print("\nTAREFA 6: Qual é o gênero mais popular na lista?")
print("O gênero mais popular na lista é: ", most_popular_gender(data_list))
# Out:
# TAREFA 6: Qual é o gênero mais popular na lista?
# O gênero mais popular na lista é:  Masculino

# %%
# ------------ NÃO MUDE NENHUM CÓDIGO AQUI ------------
assert type(most_popular_gender(data_list)) is str, "TAREFA 6: Tipo incorreto no retorno. Deveria retornar uma string."
assert most_popular_gender(data_list) == "Masculino", "TAREFA 6: Resultado de retorno incorreto!"
# -----------------------------------------------------

# %%
# Se tudo está rodando como esperado, verifique este gráfico!
gender_list = column_to_list(data_list, -2)
types = ["Male", "Female"]
quantity = count_gender(data_list)
y_pos = list(range(len(types)))
plt.bar(y_pos, quantity)
plt.ylabel('Quantidade')
plt.xlabel('Gênero')
plt.xticks(y_pos, types)
plt.title('Quantidade por Gênero')
plt.show(block=True)

# %%
column_to_list(data_list, -3)
# Out:
# ['Customer',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Customer',
#  'Customer',
#  'Customer',
#  'Subscriber',
#  'Customer',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Customer',
#  'Subscriber',
#  'Customer',
#  'Subscriber',
#  'Subscriber',
#  'Customer',
#  'Subscriber',
#  'Subscriber',
#  'Customer',
#  'Subscriber',
#  'Customer',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Customer',
#  'Customer',
#  'Subscriber',
#  'Subscriber',
#  'Customer',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Customer',
#  'Customer',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Subscriber',
#  'Customer',
# ...

# %%
input("Aperte Enter para continuar...")
# Agora sabemos como acessar as features, vamos contar quantos Male (Masculinos) e Female (Femininos) o dataset tem
# TAREFA 7
# TODO: Conte cada gênero. Você não deveria usar uma função parTODO isso.
customer = 0
subscriber = 0
for tipo in range(len(data_list)):
    if (data_list[tipo][5] == "Customer"):
        customer = customer + 1
    elif (data_list[tipo][5] == "Subscriber"):
        subscriber = subscriber + 1

print(customer)
print(subscriber)
# Out:
# Aperte Enter para continuar...
# 317162
# 1234339

# %%
# Verificando o resultado
print("\nTAREFA 7: Imprimindo quantos tipos customer e subscriber nós encontramos")
print("Customer: ", customer, "\nSubscriber: ", subscriber)
# Out:
# TAREFA 7: Imprimindo quantos tipos customer e subscriber nós encontramos
# Customer:  317162
# Subscriber:  1234339

# %%
def most_popular_tipos(data_list):
    customer = 0
    subscriber = 0
    for tipos in range(len(data_list)):
        if (data_list[tipos][5] == "Customer"):
            customer = customer + 1
        elif (data_list[tipos][5] == "Subscriber"):
            subscriber = subscriber + 1
    
    if customer > subscriber:
        answer = "Customer"
    else:
        answer = "Subscriber"
    return answer

# %%
def count_type(data_list):
    customer = 0
    subscriber = 0
    for tipos in range(len(data_list)):
        if (data_list[tipos][5] == "Customer"):
            customer = customer + 1
        elif (data_list[tipos][5] == "Subscriber"):
            subscriber = subscriber + 1
    return [customer, subscriber]

# %%
count_type(data_list)
# Out:
# [317162, 1234339]

# %%
print("\nTAREFA 7: Qual é o tipo de usuário mais popular na lista?")
print("O tipo mais popular de usuário na lista é: ", most_popular_tipos(data_list))
# Out:
# TAREFA 7: Qual é o tipo de usuário mais popular na lista?
# O tipo mais popular de usuário na lista é:  Subscriber

# %%
input("Aperte Enter para continuar...")
# TAREFA 7
# TODO: Crie um gráfico similar para user_types. Tenha certeza que a legenda está correta.
user_type = column_to_list(data_list, -3)
types = ["Subscriber", "Customer"]
quantity = count_type(data_list)
y_pos = list(range(len(types)))
plt.bar(y_pos, quantity)
plt.ylabel('Quantidade')
plt.xlabel('Tipo de usuário')
plt.xticks(y_pos, types)
plt.title('Quantidade por tipo de usuário')
plt.show(block=True)
print("\nTAREFA 7: Verifique o gráfico!")
# Out:
# Aperte Enter para continuar...
# TAREFA 7: Verifique o gráfico!

# %%
input("Aperte Enter para continuar...")
# TAREFA 8
# TODO: Responda a seguinte questão
male, female = count_gender(data_list)
print("\nTAREFA 8: Por que a condição a seguir é Falsa?")
print("male + female == len(data_list):", male + female == len(data_list))
answer = "Porque além de Masculino e Feminino há também campos vazios, por isso a soma de masculinos e femininos não são iguais ao total de registros"
print("resposta:", answer)
# Out:
# Aperte Enter para continuar...
#
# TAREFA 8: Por que a condição a seguir é Falsa?
# male + female == len(data_list): False
# resposta: Porque além de Masculino e Feminino há também campos vazios, por isso a soma de masculinos e femininos não são iguais ao total de registros

# %%
# ------------ NÃO MUDE NENHUM CÓDIGO AQUI ------------
assert answer != "Escreva sua resposta aqui.", "TAREFA 8: Escreva sua própria resposta!"
# -----------------------------------------------------

# %%
input("Aperte Enter para continuar...")
# Vamos trabalhar com trip_duration (duração da viagem) agora. Não conseguimos tirar alguns valores dele.
# TAREFA 9
# TODO: Ache a duração de viagem Mínima, Máxima, Média, e Mediana.
# Você não deve usar funções prontas parTODO isso, como max() e min().
trip_duration_list = column_to_list(data_list, 2)
min_trip = 0.
max_trip = 0.
mean_trip = 0.
median_trip = 0.

"""
Calcula a media da viagem(trip) recebe um atribulo do tipo lista com a duração das viagens.
"""
def calcula_media(lista):
    total = 0
    for trip in range(len(lista)):
        total = total + int(lista[trip])
        #print(trip_duration_list[trip])
        mean_trip = total / len(lista)
    return mean_trip

#chama a função criada pra calcular a media da trip(viagem) e atribui para a variavel mean_trip
mean_trip = round(calcula_media(trip_duration_list))

def calcula_minimo(lista):
    min_trip = int(lista[0])
    for mini in range(len(lista)):
       if(int(lista[mini]) < min_trip):
        min_trip = int(lista[mini])
    return min_trip
        
#chama a funcao criada pra calcular o menor valor de trip(viagem) e atribiu para a variavel min_trip
min_trip = calcula_minimo(trip_duration_list)

def calcula_maior(lista):
    max_trip = int(lista[0])
    for maximo in range(len(lista)):
        if int(lista[maximo]) > max_trip:
            max_trip = int(lista[maximo])
    return max_trip


#chama a funcao criada pra calcular o maior valor de trip(viagem) e atribiu para a variavel min_trip
max_trip = calcula_maior(trip_duration_list)


#def calcula_mediana(lista):
    

median_trip = calcula_mediana(trip_duration_list)

print("\nTAREFA 9: Imprimindo o mínimo, máximo, média, e mediana")
print("Min: ", min_trip, "Max: ", max_trip, "Média: ", mean_trip, "Mediana: ", median_trip)
